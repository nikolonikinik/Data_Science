# %% [markdown]
# # Обучение с учителем: качество модели

# %% [markdown]
# **Описание проекта:**
#
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
#
# **Описание данных:**
#
# Данные представлены в четырёх датасетах: `market_file.csv`, `market_money.csv`, `market_time.csv`, `money.csv`.
# 1. Файл `market_file.csv` содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении. Описание данных:
#     - `id` — номер покупателя в корпоративной базе данных.
#     - `Покупательская активность` — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
#     - `Тип сервиса` — уровень сервиса, например «премиум» и «стандарт».
#     - `Разрешить сообщать` — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
#     - `Маркет_актив_6_мес` — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
#     - `Маркет_актив_тек_мес` — количество маркетинговых коммуникаций в текущем месяце.
#     - `Длительность` — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
#     - `Акционные_покупки` — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
#     - `Популярная_категория` — самая популярная категория товаров у покупателя за последние 6 месяцев.
#     - `Средний_просмотр_категорий_за_визит` — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
#     - `Неоплаченные_продукты_штук_квартал` — общее число неоплаченных товаров в корзине за последние 3 месяца.
#     - `Ошибка_сервиса` — число сбоев, которые коснулись покупателя во время посещения сайта.
#     - `Страниц_за_визит` — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
#
# 2. Файл `market_money.csv` хранит данные о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом. Описание данных:
#     - `id` — номер покупателя в корпоративной базе данных.
#     - `Период` — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
#     - `Выручка` — сумма выручки за период.
#
#
# 3. Файл `market_time.csv` — это данные о времени (в минутах), которое покупатель провёл на сайте в течение периода. Описание данных:
#     - `id` — номер покупателя в корпоративной базе данных.
#     - `Период` — название периода, во время которого зафиксировано общее время.
#     - `минут` — значение времени, проведённого на сайте, в минутах.
#
#
# 4. Файл `money.csv` — это данные о среднемесячной прибыли продавца за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю. Описание данных:
#     - `id` — номер покупателя в корпоративной базе данных.
#     - `Прибыль` — значение прибыли.
#
# **Ход решения задачи** уже сформулирован руководителем:
# 1) Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
#
# 2) Нужно собрать данные по клиентам по следующим группам:
# - Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
# - Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
# - Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
# - Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.
#
# 3) Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
#
# 4) В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
#
# 5) Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.
#
# 6) Нужно реализовать описание решения.
#
#
# **План работы над проектом:**
#
# 1) **Загрузка и изучение данных** на предмет возникновения в них дубликатов, пропусков и ошибок в типах данных.
#
# 2) **Предобработка данных** — на этом этапе мы обработаем все недостатки исходных данных, найденные на предыдущем шаге.
#
# 3) **Исследовательский анализ** — детальнее ознакомимся с данными и разберёмся с выбросами в них.
#
# 4) **Объединение таблиц** — скомпонуем все данные в одну таблицу.
#
# 5) **Корреляционный анализ** — изучим взаимосвязи между признаками, которые впоследствии используем в машинном обучении.
#
# 6) **Использование пайплайнов** — создадим пайплайн для выбора оптимальной модели и её гиперпараметров.
#
# 7) **Анализ важности признаков** — рассмотрим степень влияния различных признаков на итоговое предсказание, и найдём те из них, которые вносят наибольший и наименьший вклад.
#
# 8) **Сегментация покупателей** — выделим категорию пользователей, которой нужно уделить особое внимание в целях лучшего удержания их на сайте и предложим ряд решений, помогающих достичь этой цели.
#
# 9) Сделаем **итоговый вывод** о том, как увеличить покупательскую активность, а также кратко подытожим основные итоги исследования.

# %% [markdown]
# # Импорт и настройка библиотек

# %%
# !pip install phik -q
# !pip install yellowbrick -q
# !pip install optuna -q
# !pip install optuna.integration -q
# !pip install imbalanced_learn -q
# !pip install scikit-learn==1.1.3 -q
# !pip install matplotlib==3.5.2 -q
# !pip install shap -q

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import phik
import shap

from scipy import stats as st
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    accuracy_score, mean_squared_error, mean_absolute_error, r2_score, confusion_matrix,
    precision_score, recall_score, f1_score, roc_auc_score, roc_curve, fbeta_score,
    RocCurveDisplay, ConfusionMatrixDisplay
)

from sklearn.preprocessing import (
    StandardScaler, OneHotEncoder, MinMaxScaler,
    OrdinalEncoder, LabelEncoder, PolynomialFeatures
)
from sklearn.dummy import DummyClassifier

from yellowbrick.classifier import ROCAUC
    
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import RandomUnderSampler

from optuna.integration import OptunaSearchCV
from optuna import visualization
from optuna import distributions
    
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import rcParams, rcParamsDefault
rcParams['figure.figsize'] = 10, 6
# %config InlineBackend.figure_format = 'svg'
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Загрузка данных

# %%
def plot_describe (t, x_l, y_l): # Заранее пропишем функцию, подписывающую название графика и осей
    plt.title(t)                 # Здесь параметр t будет отвечать за название графика  
    plt.xlabel(x_l)              # Параметр x_l — за подпись горизонтальной оси
    plt.ylabel(y_l)              # Параметр y_l — за подпись вертикальной оси
    plt.show()
    
RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# Считаем csv-файлы:

# %%
df_main = pd.read_csv("/datasets/market_file.csv", sep = ',')
df_money = pd.read_csv("/datasets/market_money.csv", sep = ',')
df_time = pd.read_csv("/datasets/market_time.csv", sep = ',', decimal=',')
df_profit = pd.read_csv("/datasets/money.csv", sep = ';', decimal=',')

# %% [markdown]
# Изучим общую информацию о датасетах. Однако, прежде чем мы приступим к их разбору, напишем **вспомогательную функцию**. Так проводить анализ будет быстрее и удобнее:

# %%
def describe_data (data):
    print('Первые пять строк таблицы:')
    display(data.head())
    print('\n', 'Последние пять строк таблицы:')
    display(data.tail())
    print('\n', 'Общая информация о датасете:', '\n')
    display(data.info())
    print('\n', 'Описательные статистики датасета:')
    display(data.describe().round(2))
    print('\n', 'Количество дубликатов в данных:')
    display(data.duplicated().sum())

# %%
describe_data(df_main) # Изучаем данные о поведении покупателей на сайте
# Out:
# Первые пять строк таблицы:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
describe_data(df_money) # Изучаем данные о выручке, которую магазин получает с покупателей
# Out:
# Первые пять строк таблицы:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6
#  Последние пять строк таблицы:
#           id               Период  Выручка
# 3895  216646  препредыдущий_месяц   4725.0
# 3896  216646     предыдущий_месяц   4923.0
# 3897  216647     предыдущий_месяц   4720.0
# 3898  216647  препредыдущий_месяц   5183.0
# 3899  216647        текущий_месяц   4448.3
#  Общая информация о датасете:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB
# None
# ...

# %%
describe_data(df_time) # Изучаем данные о времени, проведённом покупателями на сайте
# Out:
# Первые пять строк таблицы:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13
#  Последние пять строк таблицы:
#           id            Период  минут
# 2595  216645     текущий_месяц     18
# 2596  216646  предыдцщий_месяц     18
# 2597  216646     текущий_месяц      7
# 2598  216647     текущий_месяц     10
# 2599  216647  предыдцщий_месяц     15
#  Общая информация о датасете:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
# None
#  Описательные статистики датасета:
#               id    минут
# ...

# %%
describe_data(df_profit) # Изучаем данные о среднемесячной прибыли продавца за последние 3 месяца
# Out:
# Первые пять строк таблицы:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21
#  Последние пять строк таблицы:
#           id  Прибыль
# 1295  216643     4.44
# 1296  216644     6.11
# 1297  216645     3.29
# 1298  216646     4.03
# 1299  216647     3.28
#  Общая информация о датасете:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB
# None
#  Описательные статистики датасета:
#               id  Прибыль
# count    1300.00  1300.00
# mean   215997.50     4.00
# std       375.42     1.01
# min    215348.00     0.86
# 25%    215672.75     3.30
# 50%    215997.50     4.04
# 75%    216322.25     4.67
# max    216647.00     7.43
# ...

# %% [markdown]
# **Промежуточный вывод:**
#
# Проблем при выгрузке данных не возникло, пропусков и очевидных дубликатов нет. Однако, сразу можем заметить, что в данных допущены стилистические ошибки в названиях столбцов и в содержащихся в этих столбцах данных. Исправим эти ошибки на следующем этапе.

# %% [markdown]
# #  Предобработка данных

# %% [markdown]
# Исправим стилистические ошибки в названиях столбцов. Для этого сперва приведём все названия к нижнему регистру:

# %%
df_main.columns = df_main.columns.str.lower()
df_money.columns = df_money.columns.str.lower()
df_time.columns = df_time.columns.str.lower()
df_profit.columns = df_profit.columns.str.lower()

# %% [markdown]
# После чего переименуем столбцы в датафрейме `df_main` для лучшего их восприятия:

# %%
df_main.columns = [
    'id',
    'покупательская_активность',
    'тип_сервиса',
    'разрешить_сообщать',
    'маркет_актив_6_мес',
    'маркет_актив_тек_мес',
    'длительность',
    'акционные_покупки',
    'популярная_категория',
    'средний_просмотр_категорий_за_визит',
    'неоплаченные_продукты_штук_квартал',
    'ошибка_сервиса',
    'страниц_за_визит',
]  # Переименовываем столбцы датафрейма с данными о поведении покупателей на сайте

# %% [markdown]
# Убедимся в том, что все столбцы переименованы верно:

# %%
df_main.head(5)
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %%
df_money.head(5)
# Out:
#        id               период  выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %%
df_time.head(5)
# Out:
#        id            период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %%
df_profit.head(5)
# Out:
#        id  прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %% [markdown]
# Теперь, когда устранены очевидные ошибки, перейдём к менее очевидным, а именно — к поиску неявных дубликатов. Для этого проверим сперва датасет с данными о поведении покупателей на сайте. Данные выведем в словарь, в котором ключ будет представлять собой название столбца, а значение — список его уникальных значений:

# %%
[{i: df_main[i].unique()} for i in df_main.columns if df_main[i].dtype == 'object']
# Out:
# [{'покупательская_активность': array(['Снизилась', 'Прежний уровень'], dtype=object)},
#  {'тип_сервиса': array(['премиум', 'стандартт', 'стандарт'], dtype=object)},
#  {'разрешить_сообщать': array(['да', 'нет'], dtype=object)},
#  {'популярная_категория': array(['Товары для детей', 'Домашний текстиль', 'Косметика и аксесуары',
#          'Техника для красоты и здоровья', 'Кухонная посуда',
#          'Мелкая бытовая техника и электроника'], dtype=object)}]

# %% [markdown]
# Заметим, что в столбце `тип_сервиса` присутствуют неявные дубликаты. К тому же, в некоторых столбцах допущены стилистические ошибки в записи данных, поэтому исправим этот недочёт:

# %%
df_main['покупательская_активность'].replace({'Снизилась': 'снизилась', 'Прежний уровень': 'прежний_уровень'}, inplace=True)
df_main['тип_сервиса'].replace({'стандартт': 'стандарт'}, inplace=True)
df_main['популярная_категория'].replace({
    'Товары для детей': 'товары_для_детей', 'Мелкая бытовая техника и электроника': 'мелкая_бытовая_техника_и_электроника',
    'Косметика и аксесуары': 'косметика_и_аксессуары', 'Кухонная посуда': 'кухонная_посуда',
    'Техника для красоты и здоровья': 'техника_для_красоты_и_здоровья', 'Домашний текстиль': 'домашний_текстиль'
}, inplace=True)

# %% [markdown]
# Убедимся в том, что все стилистические ошибки исправлены:

# %%
[{i: df_main[i].unique()} for i in df_main.columns if df_main[i].dtype == 'object']
# Out:
# [{'покупательская_активность': array(['снизилась', 'прежний_уровень'], dtype=object)},
#  {'тип_сервиса': array(['премиум', 'стандарт'], dtype=object)},
#  {'разрешить_сообщать': array(['да', 'нет'], dtype=object)},
#  {'популярная_категория': array(['товары_для_детей', 'домашний_текстиль', 'косметика_и_аксессуары',
#          'техника_для_красоты_и_здоровья', 'кухонная_посуда',
#          'мелкая_бытовая_техника_и_электроника'], dtype=object)}]

# %% [markdown]
# Также проверим, не появилось ли новых дубликатов в данных ввиду замены значений `стандартт` на `стандарт`:

# %%
df_main.duplicated().sum() # Не появилось
# Out:
# 0

# %% [markdown]
# Проделаем аналогичные действия и с другими датафреймами. Изучим уникальные значения в датафрейме с данными о выручке, которую магазин получает с покупателей:

# %%
[{i: df_money[i].unique()} for i in df_money.columns if df_money[i].dtype == 'object']
# Out:
# [{'период': array(['препредыдущий_месяц', 'текущий_месяц', 'предыдущий_месяц'],
#         dtype=object)}]

# %% [markdown]
# Проблем со значениями нет. Далее изучим уникальные значения в данных о времени, проведённом покупателями на сайте:

# %%
[{i: df_time[i].unique()} for i in df_time.columns if df_time[i].dtype == 'object']
# Out:
# [{'период': array(['текущий_месяц', 'предыдцщий_месяц'], dtype=object)}]

# %% [markdown]
# Исправим ошибки, допущенные в записи данных:

# %%
df_time['период'].replace({'предыдцщий_месяц': 'предыдущий_месяц'}, inplace=True)

# %% [markdown]
# Убедимся в том, что ошибки исправлены:

# %%
[{i: df_time[i].unique()} for i in df_time.columns if df_time[i].dtype == 'object']
# Out:
# [{'период': array(['текущий_месяц', 'предыдущий_месяц'], dtype=object)}]

# %% [markdown]
# В последнем датафрейме с данными о среднемесячной прибыли продавца за последние 3 месяца уже по общей информации из предыдущего этапа можем заметить отсутствие строковых данных. Поэтому дополнительных действий, аналогичных проведённым выше, в данном случае проводить не будем.

# %% [markdown]
# **Промежуточный вывод:**
#
# На данном шаге обработаны явные и неявные дубликаты, а также исправлены стилистические ошибки в данных. Пропуски отсутствуют, типы данных не требуют дополнительной обработки.

# %% [markdown]
# # Исследовательский анализ данных

# %% [markdown]
# На данном этапе мы детальнее изучим параметры на предмет возникновения аномалий и выбросов в данных. Для этого рассмотрим количественные и категориальные признаки по отдельности. Но для этого сперва отсортируем их в два отдельных списка:

# %%
num_cols = [] 
cat_cols = []
for i in df_main.columns:
    if df_main[i].dtype == 'object':
        cat_cols.append(i)
    else:
        if (i != 'id'):
            num_cols.append(i)
print('Количественные признаки:', num_cols, '\n')
print('Категориальные признаки:', cat_cols, '\n')
# Out:
# Количественные признаки: ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит']
#
# Категориальные признаки: ['покупательская_активность', 'тип_сервиса', 'разрешить_сообщать', 'популярная_категория']

# %% [markdown]
# Также, в соответствии с условием задачи, отберём покупателей, которые совершали покупки за последние три месяца:

# %%
fickle_clients = df_money.loc[df_money['выручка'] == 0, 'id'].unique()
df_main = df_main.loc[~df_main['id'].isin(fickle_clients), :]
df_money = df_money.loc[~df_money['id'].isin(fickle_clients), :]
df_time = df_time.loc[~df_time['id'].isin(fickle_clients), :]
df_profit = df_profit[~df_profit['id'].isin(fickle_clients)]

# %% [markdown]
# ## Количественные признаки

# %% [markdown]
# Начнём изучение количественных признаков в том же порядке, в котором они идут в датасете с данными о поведении покупателей на сайте. Продолжим признаками из остальных датасетов. Для каждого из признаков построим гистограмму и диаграмму размаха, а также изучим влияние признака на клиентов с прежним и снизившимся уровнями активности.

# %% [markdown]
# ### Признак `маркет_актив_6_мес`

# %%
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['маркет_актив_6_мес'],
         bins=15, alpha=0.5, color='orange', label='прежняя активность')
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'снизилась']['маркет_актив_6_мес'],
         bins=15, alpha=0.5, color='blue', label='сниженная активность')
plt.legend(loc='upper right')
plot_describe('Гистограммы признака "маркет_актив_6_мес"',
              'Среднемесячное количество рекламы на покупателя', 'Количество значений')

# %%
plt.boxplot([df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['маркет_актив_6_мес'], 
            df_main.loc[df_main['покупательская_активность'] == 'снизилась']['маркет_актив_6_мес']])
plt.xticks([1, 2], ['прежняя активность', 'сниженная активность'])
plot_describe('Диаграммы размаха признака "маркет_актив_6_мес"', '', 'Среднемесячное количество рекламы на покупателя')

# %% [markdown]
# Заметны выбросы на диаграммах размаха. Определим их долю от общего числа строк в датасете:

# %%
print(f'Доля строк с выбросами: {round(len(df_main.query("маркет_актив_6_мес < 2.4")) / len(df_main) * 100, 1)}%')
# Out:
# Доля строк с выбросами: 2.8%

# %% [markdown]
# **Промежуточные выводы:**
# - число выбросов невелико, их значения вполне объяснимы: вероятно, на некоторых клиентов попросту приходится малое число маркетинговых коммуникаций;
# - по графикам можно выдвинуть предварительную гипотезу о том, что на пользователей, чья активность в последнее время снизилась, приходится меньшее число рекламных предложений. Возможно, стоит увеличить количество рассылок и показов рекламы для таких клиентов.

# %% [markdown]
# ### Признак `маркет_актив_тек_мес`

# %%
(df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['маркет_актив_тек_мес']
    .value_counts().plot.bar(color='orange', alpha=0.5, label='прежняя активность'))
(df_main.loc[df_main['покупательская_активность'] == 'снизилась']['маркет_актив_тек_мес']
 .value_counts().plot.bar(color='blue', alpha=0.5, label='сниженная активность'))
plt.legend(loc='upper right')
plot_describe('Столбчатые диаграммы признака "маркет_актив_тек_мес"',
              'Количество рекламы в текущем месяце', 'Количество значений')

# %% [markdown]
# **Промежуточные выводы:**
# - ввиду дискретности значений признака диаграмма размаха будет обладать малой информативностью, поэтому строить её мы не будем;
# - также вместо гистограммы в данном случае лучше использовать столбчатую диаграмму;
# - пока что выдвинутая ранее гипотеза косвенно подтверждается, так как мы можем увидеть уменьшение количества рекламных предложений у пользователей со сниженной активностью.

# %% [markdown]
# ### Признак `длительность`

# %%
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['длительность'],
         bins=30, alpha=0.5, color='orange', label='прежняя активность')
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'снизилась']['длительность'],
         bins=30, alpha=0.5, color='blue', label='сниженная активность')
plt.legend(loc='upper right')
plot_describe('Гистограммы признака "длительность"',
              'Количество дней с момента регистрации пользователя', 'Количество значений')

# %%
plt.boxplot([df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['длительность'], 
            df_main.loc[df_main['покупательская_активность'] == 'снизилась']['длительность']])
plt.xticks([1, 2], ['прежняя активность', 'сниженная активность'])
plot_describe('Диаграммы размаха признака "длительность"', '', 'Количество дней с момента регистрации пользователя')

# %% [markdown]
# **Промежуточные выводы:**
# - выбросов нет;
# - можем отметить, что пользователи со сниженной активностью в целом дольше зарегистрированы. В теории часть из них может негативно реагировать на какие-то изменения в подходе к оформлению рекламы или сайта (за счёт чего и снижается их активность).

# %% [markdown]
# ### Признак `акционные_покупки`

# %%
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['акционные_покупки'],
         bins=30, alpha=0.5, color='orange', label='прежняя активность')
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'снизилась']['акционные_покупки'],
         bins=30, alpha=0.5, color='blue', label='сниженная активность')
plt.legend(loc='upper right')
plot_describe('Гистограммы признака "акционные_покупки"',
              'Среднемесячная доля покупок по акции', 'Количество значений')

# %%
plt.boxplot([df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['акционные_покупки'], 
            df_main.loc[df_main['покупательская_активность'] == 'снизилась']['акционные_покупки']])
plt.xticks([1, 2], ['прежняя активность', 'сниженная активность'])
plot_describe('Диаграммы размаха признака "акционные_покупки"', '', 'Среднемесячная доля покупок по акции')

# %% [markdown]
# Заметны выбросы на диаграмме размаха. Определим их долю от общего числа строк в датасете:

# %%
print(f'Доля строк с выбросами: {round(len(df_main.query("акционные_покупки > 0.5")) / len(df_main) * 100, 1)}%')
# Out:
# Доля строк с выбросами: 13.0%

# %% [markdown]
# **Промежуточные выводы:**
# - при изучении данного признака обнаружились выбросы в данных, причём их доля внушительна: порядка 13 процентов. Однако, нет оснований считать данные ошибочными. Поэтому удалять или видоизменять эти значения мы не будем. При этом стоит отметить, что все выбросы приходятся на пользователей, чья активность не изменилась, т.е., вероятно, они не так часто пользуются акциями;
# - кардинально противоположную картину можно наблюдать у клиентов со сниженной активностью. Их заинтересованность в акционных предложениях ощутимо выше, что может свидетельствовать о том, что эти клиенты более импульсивны и, возможно, в принципе приобретают товары на сайте исключительно в рамках акций, после чего их интерес резко угасает.

# %% [markdown]
# ### Признак `средний_просмотр_категорий_за_визит`

# %%
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['средний_просмотр_категорий_за_визит'],
         bins=6, alpha=0.5, color='orange', label='прежняя активность')
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'снизилась']['средний_просмотр_категорий_за_визит'],
         bins=6, alpha=0.5, color='blue', label='сниженная активность')
plt.legend(loc='upper right')
plot_describe('Гистограмма признака "средний_просмотр_категорий_за_визит"',
              'Среднемесячное количество категорий, просмотренных пользователем', 'Количество значений')

# %%
plt.boxplot([df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['средний_просмотр_категорий_за_визит'], 
            df_main.loc[df_main['покупательская_активность'] == 'снизилась']['средний_просмотр_категорий_за_визит']])
plt.xticks([1, 2], ['прежняя активность', 'сниженная активность'])
plot_describe('Диаграмма размаха признака "средний_просмотр_категорий_за_визит"', '',
              'Среднемесячное количество категорий, просмотренных пользователем')

# %% [markdown]
# **Промежуточный вывод:**
#
# Для пользователей со сниженным уровнем активности характерно меньшее число просматриваемых за одно посещение категорий, что может быть связано с привлечением их в магазин акцией, в рамках которой они покупают товары из одной-двух интересующих их категорий, а в другие даже не заглядывают. Возможно, введение персонализированных подборок товаров или функции "Вместе с этим товаром также берут..." помогло бы продать таким пользователям большее число товаров.

# %% [markdown]
# ### Признак `неоплаченные_продукты_штук_квартал`

# %%
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['неоплаченные_продукты_штук_квартал'],
         bins=10, alpha=0.5, color='orange', label='прежняя активность')
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'снизилась']['неоплаченные_продукты_штук_квартал'],
         bins=10, alpha=0.5, color='blue', label='сниженная активность')
plt.legend(loc='upper right')
plot_describe('Гистограммы признака "неоплаченные_продукты_штук_квартал"',
              'Количество неоплаченных товаров в корзине за 3 месяца', 'Количество значений')

# %%
plt.boxplot([df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['неоплаченные_продукты_штук_квартал'], 
            df_main.loc[df_main['покупательская_активность'] == 'снизилась']['неоплаченные_продукты_штук_квартал']])
plt.xticks([1, 2], ['прежняя активность', 'сниженная активность'])
plot_describe('Диаграммы размаха признака "неоплаченные_продукты_штук_квартал"', '',
              'Общее число неоплаченных товаров в корзине за 3 месяца')

# %% [markdown]
# Заметны выбросы на диаграмме размаха. Определим их долю от общего числа строк в датасете:

# %%
print(f'Доля строк с выбросами: {round(len(df_main.query("неоплаченные_продукты_штук_квартал > 8")) / len(df_main) * 100, 1)}%')
# Out:
# Доля строк с выбросами: 1.1%

# %% [markdown]
# **Промежуточные выводы:**
# - обнаружены малочисленные выбросы, однако их природа вполне объяснима: некоторые покупатели предпочитают сперва добавить товары в корзину, а уже только потом купить те из них, которые им нужны в ближайшем времени, оставив большую часть корзины до лучших времён. Возникновения подобных ситуаций можно было бы избежать добавлением (или упрощением доступа к уже существующей) функции "Добавить в Избранное";
# - количество неоплаченных товаров у клиентов со сниженной активностью ощутимо больше, чем у более "стабильных" клиентов. Это может свидетельствовать о том, что такие пользователи если и интересуются несколькими разделами, то всё же не приобретают большинство товаров из них. Вероятно, их покупки на деле ограничиваются одним-двумя акционными товарами, а остальное попадает в корзину из чистого любопытства.

# %% [markdown]
# ### Признак `ошибка_сервиса`

# %%
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['ошибка_сервиса'],
         bins=10, alpha=0.5, color='orange', label='прежняя активность')
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'снизилась']['ошибка_сервиса'],
         bins=10, alpha=0.5, color='blue', label='сниженная активность')
plt.legend(loc='upper right')
plot_describe('Гистограммы признака "ошибка_сервиса"',
              'Число сбоев у покупателя во время посещения сайта', 'Количество значений')

# %%
plt.boxplot([df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['ошибка_сервиса'], 
            df_main.loc[df_main['покупательская_активность'] == 'снизилась']['ошибка_сервиса']])
plt.xticks([1, 2], ['прежняя активность', 'сниженная активность'])
plot_describe('Диаграммы размаха признака "ошибка_сервиса"', '',
              'Число сбоев у покупателя во время посещения сайта')

# %% [markdown]
# **Промежуточные выводы:**
# - выбросов не обнаружено;
# - распределение признаков выглядит близким к нормальному;
# - явных различий между клиентами с разными показателями активности не наблюдается.

# %% [markdown]
# ### Признак `страниц_за_визит`

# %%
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['страниц_за_визит'],
         bins=20, alpha=0.5, color='orange', label='прежняя активность')
plt.hist(df_main.loc[df_main['покупательская_активность'] == 'снизилась']['страниц_за_визит'],
         bins=20, alpha=0.5, color='blue', label='сниженная активность')
plt.legend(loc='upper right')
plot_describe('Гистограммы признака "страниц_за_визит"',
              'Среднее количество страниц за одно посещение сайта', 'Количество значений')

# %%
plt.boxplot([df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['страниц_за_визит'], 
            df_main.loc[df_main['покупательская_активность'] == 'снизилась']['страниц_за_визит']])
plt.xticks([1, 2], ['прежняя активность', 'сниженная активность'])
plot_describe('Диаграммы размаха признака "страниц_за_визит"', '',
              'Среднее количество страниц за одно посещение сайта')

# %% [markdown]
# **Промежуточный вывод:**
#
# В целом, данные по этому признаку подтверждают выдвинутые ранее гипотезы. Пользователи со сниженной активностью просматривают меньшее количество страниц (равно как и категорий) за визит, что говорит о низком уровне их заинтересованности в товарах иных, кроме того, за которым они изначально и пришли (вероятно, привлечённые изначально акцией).

# %% [markdown]
# ### Признак `выручка`

# %% [markdown]
# Ещё на этапе загрузки данных при ознакомлении с описательными статистиками датасета `df_money` мы могли заметить, что максимальное значение в данном столбце сильно выделяется на фоне остальных показателей. Покажем эти статистики ещё раз:

# %%
df_money['выручка'].describe()
# Out:
# count      3891.000000
# mean       5033.718890
# std        1768.471286
# min        2758.700000
# 25%        4592.000000
# 50%        4959.000000
# 75%        5363.200000
# max      106862.200000
# Name: выручка, dtype: float64

# %%
p_01 = df_money['выручка'].quantile(0.01) # Ознакомимся с 1-ым процентилем
p_99 = df_money['выручка'].quantile(0.99) # Ознакомимся с 99-ым процентилем
display(p_01)
display(p_99)
# Out:
# 3326.2
# 6958.07

# %%
print(df_money['выручка'].loc[df_money['выручка'] > 7000]) # Посмотрим, сколько значений вообще превышают 99-ый процентиль
# Out:
# 98      106862.2
# 173       7104.0
# 262       7605.3
# 306       7160.0
# 435       7799.4
# 566       7467.9
# 631       7212.3
# 679       7047.8
# 843       7160.9
# 949       7019.5
# 1003      7401.6
# 1100      7063.0
# 1247      7208.8
# 1250      7325.4
# 1340      7112.8
# 1392      7167.4
# 1481      7557.0
# 1573      7374.0
# 1584      7108.4
# 1602      7038.8
# 1632      7401.6
# 1770      7338.2
# 1925      7310.0
# 2205      7182.2
# 2266      7410.0
# 2388      7547.8
# 2400      7075.2
# 2419      7082.2
# 2550      7054.2
# 2621      7314.0
# 2720      7075.8
# 2922      7370.6
# 2951      7007.2
# 3581      7082.0
# 3620      7114.2
# Name: выручка, dtype: float64

# %%
print(df_money['выручка'].loc[df_money['выручка'] < 3000]) # Посмотрим, сколько значений не превышают 1-ый процентиль
# Out:
# 356     2758.7
# 392     2960.0
# 649     2890.0
# 662     2909.0
# 2485    2952.2
# 3860    2970.0
# Name: выручка, dtype: float64

# %% [markdown]
# Среди прочих выбиваeтся аномальное значение 106862.2. Удалим строку, содержащую это значение, и посмотрим на то, как изменятся описательные статистики:

# %%
df_money = df_money.loc[df_money['выручка'] < 8000].reset_index(drop = True) 
df_money['выручка'].describe()
# Out:
# count    3890.000000
# mean     5007.541902
# std       679.235737
# min      2758.700000
# 25%      4592.000000
# 50%      4959.000000
# 75%      5363.000000
# max      7799.400000
# Name: выручка, dtype: float64

# %%
df_money['выручка'].hist(bins=20) 
plot_describe('Гистограмма признака "выручка"',
              'Сумма выручки за период', 'Количество значений')

# %%
plt.boxplot(df_money['выручка'])
plot_describe('Диаграмма размаха признака "выручка"', '', 'Сумма выручки за период')

# %% [markdown]
# Заметны выбросы на диаграмме размаха. Определим их долю от общего числа строк в датасете:

# %%
print(f'Доля строк с выбросами по нижней границе:\
      {round(len(df_money.query("выручка < 3500")) / len(df_money) * 100, 1)}%')
print(f'Доля строк с выбросами по верхней границе:\
      {round(len(df_money.query("выручка > 6400")) / len(df_money) * 100, 1)}%')
# Out:
# Доля строк с выбросами по нижней границе:      1.8%
# Доля строк с выбросами по верхней границе:      3.5%

# %% [markdown]
# **Промежуточные выводы:**
# - удалено обнаруженное аномальное значение 108862.2;
# - остальные малочисленные выбросы выглядят вполне реалистично, избавляться от них бессмысленно;
# - распределение признаков нормальное.

# %% [markdown]
# ### Признак `минут`

# %%
df_time['минут'].hist(bins=20) 
plot_describe('Гистограмма признака "минут"',
              'Время, проведённое пользователем на сайте', 'Количество значений')

# %%
plt.boxplot(df_time['минут'])
plot_describe('Диаграмма размаха признака "минут"', '', 'Время, проведённое пользователем на сайте')

# %% [markdown]
# **Промежуточные выводы:**
# - выбросов не обнаружено;
# - распределение признаков выглядит близким к нормальному со смещением влево.

# %% [markdown]
# ### Признак `прибыль`

# %%
df_profit['прибыль'].describe()
# Out:
# count    1297.000000
# mean        3.997610
# std         1.010813
# min         0.860000
# 25%         3.300000
# 50%         4.040000
# 75%         4.670000
# max         7.430000
# Name: прибыль, dtype: float64

# %%
df_profit['прибыль'].hist(bins=30) 
plot_describe('Гистограмма признака "прибыль"',
              'Прибыль с пользователя за 3 месяца', 'Количество значений')

# %%
plt.boxplot(df_profit['прибыль'])
plot_describe('Диаграмма размаха признака "прибыль"', '', 'Прибыль с пользователя за 3 месяца')

# %% [markdown]
# Заметны выбросы на диаграмме размаха. Определим их долю от общего числа строк в датасете:

# %%
print(f'Доля строк с выбросами по нижней границе:\
      {round(len(df_profit.query("прибыль < 1.4")) / len(df_money) * 100, 1)}%')
print(f'Доля строк с выбросами по верхней границе:\
      {round(len(df_profit.query("прибыль > 6.6")) / len(df_money) * 100, 1)}%')
# Out:
# Доля строк с выбросами по нижней границе:      0.2%
# Доля строк с выбросами по верхней границе:      0.2%

# %% [markdown]
# **Промежуточные выводы:**
# - обнаружены малочисленные выбросы, однако их значения отличаются от основной части данных незначительно, поэтому удалять их не будем;
# - распределение признаков выглядит близким к нормальному.

# %% [markdown]
# ## Категориальные признаки

# %% [markdown]
# Для категориальных признаков целесообразнее построить круговую диаграмму, показывающую соотношение между различными категориями. Поэтому сразу пропишем функцию, которая упростит нам работу с однотипными блоками и сделает код более лаконичным:

# %%
def pl_pie (df, column, title):
    df[column].value_counts().plot(y='count', kind='pie', autopct='%1.1f%%', ylabel='')
    plt.title(title)
    plt.show()

# %% [markdown]
# Категориальные признаки: ['покупательская_активность', 'тип_сервиса', 'разрешить_сообщать', 'популярная_категория']

# %% [markdown]
# ### Признак `покупательская_активность`

# %%
pl_pie(df_main, 'покупательская_активность', 'Уровень покупательской активности')

# %% [markdown]
# ### Признак `тип_сервиса`

# %%
(df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['тип_сервиса']
    .value_counts().plot(y='count', kind='pie', autopct='%1.1f%%', ylabel=''))
plt.title('Уровень сервиса пользователей с прежним уровнем активности')
# Out:
# Text(0.5, 1.0, 'Уровень сервиса пользователей с прежним уровнем активности')

# %%
(df_main.loc[df_main['покупательская_активность'] == 'снизилась']['тип_сервиса']
    .value_counts().plot(y='count', kind='pie', autopct='%1.1f%%', ylabel=''))
plt.title('Уровень сервиса пользователей со сниженным уровнем активности')
# Out:
# Text(0.5, 1.0, 'Уровень сервиса пользователей со сниженным уровнем активности')

# %% [markdown]
# **Промежуточный вывод:**
#
# Среди клиентов, активность которых снизилась, большее количество пользователей премиум-сегмента. Это может быть сигналом о неудовлетворённости клиентов преимуществами, которые им предлагает данный тип сервиса по сравнению с обычным. Вероятно, компании требуется улучшить условия для премиум-клиентов для повышения их покупательской активности.

# %% [markdown]
# ### Признак `разрешить_сообщать`

# %%
(df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['разрешить_сообщать']
    .value_counts().plot(y='count', kind='pie', autopct='%1.1f%%', ylabel=''))
plt.title('Согласие на рекламу пользователей с прежним уровнем активности')
# Out:
# Text(0.5, 1.0, 'Согласие на рекламу пользователей с прежним уровнем активности')

# %%
(df_main.loc[df_main['покупательская_активность'] == 'снизилась']['разрешить_сообщать']
    .value_counts().plot(y='count', kind='pie', autopct='%1.1f%%', ylabel=''))
plt.title('Согласие на рекламу пользователей со сниженным уровнем активности')
# Out:
# Text(0.5, 1.0, 'Согласие на рекламу пользователей со сниженным уровнем активности')

# %% [markdown]
# **Промежуточный вывод:**
#
# Особых различий между клиентами с разным типом активности не наблюдается. Можем предположить, что данный признак практически не оказывает влияния на снижение активности клиентов.

# %% [markdown]
# ### Признак `популярная_категория`

# %%
(df_main.loc[df_main['покупательская_активность'] == 'прежний_уровень']['популярная_категория']
    .value_counts().plot(y='count', kind='pie', autopct='%1.1f%%', ylabel=''))
plt.title('Популярные категории у пользователей с прежним уровнем активности')
# Out:
# Text(0.5, 1.0, 'Популярные категории у пользователей с прежним уровнем активности')

# %%
(df_main.loc[df_main['покупательская_активность'] == 'снизилась']['популярная_категория']
    .value_counts().plot(y='count', kind='pie', autopct='%1.1f%%', ylabel=''))
plt.title('Популярные категории у пользователей со сниженным уровнем активности')
# Out:
# Text(0.5, 1.0, 'Популярные категории у пользователей со сниженным уровнем активности')

# %% [markdown]
# **Промежуточный вывод:**
#
# У клиентов со сниженной активностью наиболее ярко выделяются три категории: товары для детей, домашний текстиль и косметика и аксессуары. Объяснить снижение активности таких пользователей можно тем, что товары из перечисленных групп по разным причинам теряют для них актуальность.

# %% [markdown]
# ### Признак `период`

# %%
pl_pie(df_money, 'период', 'Период, во время которого зафиксирована выручка')

# %%
pl_pie(df_time, 'период', 'Период, во время которого зафиксировано общее время')

# %% [markdown]
# **Промежуточные выводы:**
# - В рамках исследовательского анализа были рассмотрены количественные и категориальные признаки. Для количественных признаков построены гистограммы и диаграммы размаха, для категориальных — круговые диаграммы.
# - Было удалено аномальное значение в столбце`выручка`.
# - Пользователи со сниженной активностью просматривают меньшее количество страниц и категорий за визит, а также набирают в корзину много товаров, которые впоследствии не приобретают. Это может быть связано с привлечением их в магазин акцией, в рамках которой они покупают товары из одной-двух интересующих их категорий, а в другие даже не заглядывают. Возможно, введение персонализированных подборок товаров или функции "Вместе с этим товаром также берут..." помогло бы продать таким пользователям большее число товаров.
# - Предыдущее предположение также подтверждают и данные о покупках по акции. Заинтересованность в акционных предложениях у клиентов со сниженной активностью ощутимо выше, чем у клиентов с активностью неизменной, что может свидетельствовать о том, что эти клиенты более импульсивны и, возможно, в принципе приобретают товары на сайте исключительно в рамках акций, после чего их интерес резко угасает.
# - На пользователей, чья активность в последнее время снизилась, приходится меньшее число рекламных предложений. Возможно, стоит увеличить количество рассылок и показов рекламы для таких клиентов.
# - Можем отметить, что пользователи со сниженной активностью в целом дольше зарегистрированы. В теории часть из них может негативно реагировать на какие-то изменения в подходе к оформлению рекламы или сайта (за счёт чего и снижается их активность). Было бы неплохо собрать от них обратную связь и понять, как можно улучшить пользовательский опыт от взаимодействия с сайтом.

# %% [markdown]
# # Объединение таблиц

# %% [markdown]
# Объединим датасеты `df_main`, `df_money` и `df_time` в один общий датасет `df` для оптимизации дальнейших шагов анализа:

# %%
df_money_pivot = df_money.pivot_table(    # Создаём сводную таблицу с помесячной выручкой
    index='id', columns='период', values='выручка', aggfunc='first').reset_index()
df_money_pivot.columns = [
    'id',
    'выручка_предыдущий_месяц',
    'выручка_предпредыдущий_месяц',
    'выручка_текущий_месяц',
] # Переименовываем столбцы

df_time_pivot = df_time.pivot_table( # Создаём сводную таблицу с помесячным временем,
    index='id', columns='период', values='минут', aggfunc='first' # проведённым пользователями на сайте
).reset_index()
df_time_pivot.columns = [
    'id',
    'время_предыдущий_месяц',
    'время_текущий_месяц',
] # Переименовываем столбцы

df = pd.merge( # Объединяем сводные таблицы с датасетом df_main
    df_main, 
    pd.merge(df_money_pivot, df_time_pivot, left_index=True, right_index=True),
    left_index=True, right_index=True).drop(['id_x','id_y'], axis = 1
)
df = df.dropna()
df.set_index('id', inplace=True)
display(df.head())
df.shape
# Out:
#        покупательская_активность тип_сервиса разрешить_сообщать  \
# id
# 215349                 снизилась     премиум                 да
# 215350                 снизилась    стандарт                нет
# 215351                 снизилась    стандарт                 да
# 215352                 снизилась    стандарт                нет
# 215353                 снизилась    стандарт                 да
#
#         маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# id
# 215349                 4.4                     4           819
# 215350                 4.9                     3           539
# 215351                 3.2                     5           896
# 215352                 5.1                     3          1064
# 215353                 3.3                     4           762
#
#         акционные_покупки популярная_категория  \
# id
# 215349               0.75     товары_для_детей
# 215350               0.14    домашний_текстиль
# ...

# %% [markdown]
# # Корреляционный анализ

# %% [markdown]
# Найдём коэффициенты корреляции между всеми признаками в датасете и отобразим их при помощи тепловой карты корреляций:

# %%
plt.figure(figsize=(12, 8))
sb.heatmap(df.phik_matrix().round(2), annot=True, vmin=0, vmax=1, cmap='coolwarm')
plot_describe('Тепловая карта корреляции признаков', '', '')
# Out:
# interval columns not set, guessing: ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит', 'выручка_предыдущий_месяц', 'выручка_предпредыдущий_месяц', 'выручка_текущий_месяц', 'время_предыдущий_месяц', 'время_текущий_месяц']

# %%
df.phik_matrix(interval_cols=[
    'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
    'акционные_покупки', 'средний_просмотр_категорий_за_визит',
    'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
    'страниц_за_визит', 'выручка_предыдущий_месяц', 'выручка_предпредыдущий_месяц',
    'выручка_текущий_месяц', 'время_предыдущий_месяц', 'время_текущий_месяц'
]).style.background_gradient(vmin=0, vmax=1, cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_d2fce_row0_col0,#T_d2fce_row1_col1,#T_d2fce_row2_col2,#T_d2fce_row3_col3,#T_d2fce_row4_col4,#T_d2fce_row5_col5,#T_d2fce_row6_col6,#T_d2fce_row7_col7,#T_d2fce_row8_col8,#T_d2fce_row9_col9,#T_d2fce_row10_col10,#T_d2fce_row11_col11,#T_d2fce_row12_col12,#T_d2fce_row13_col13,#T_d2fce_row14_col14,#T_d2fce_row15_col15,#T_d2fce_row16_col16{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_d2fce_row0_col1,#T_d2fce_row1_col0,#T_d2fce_row10_col13,#T_d2fce_row13_col10{
#             background-color:  #6485ec;
#             color:  #000000;
# ...

# %% [markdown]
# **Промежуточный вывод:**
#
# На основе матрицы корреляций можно судить о сильной корреляции между некоторыми входными признаками (например, между выручкой за текущий и предыдущий месяцы), однако явных признаков сильной мультиколлинеарности (0.9 и более) с целевым признаком мы не наблюдаем.

# %% [markdown]
# # Использование пайплайнов

# %% [markdown]
# Для автоматизации машинного обучения (перебора вариантов масштабирования, выбора оптимальной модели и её гиперпараметров) в рамках данного анализа будем использовать пайплайны.
#
# Для кодирования категориальных признаков мы будем использовать `OneHotEncoder` (для бинарных признаков) и `OrdinalEncoder` (для признаков с несколькими значениями):

# %%
df_map = df.copy()
map_dict = {'прежний_уровень' : 0, 'снизилась' : 1}
df_map['покупательская_активность'] = df_map['покупательская_активность'].map(map_dict)

ohe_columns = ['разрешить_сообщать', 'популярная_категория'] # Создаём списки с названиями признаков
ord_columns = ['тип_сервиса'] 
num_columns = [ 
    'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки',
    'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал',
    'ошибка_сервиса', 'страниц_за_визит', 'выручка_предпредыдущий_месяц',
    'выручка_предыдущий_месяц', 'выручка_текущий_месяц',
    'время_предыдущий_месяц', 'время_текущий_месяц'
]           

X = df_map.drop(['покупательская_активность'], axis = 1) # Делим данные на входные и целевые
y = df_map['покупательская_активность'] 
X_train, X_test, y_train, y_test = train_test_split(  # Делим данные на тренировочные и тестовые
    X, 
    y, 
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = df_map['покупательская_активность']
) 

y_train.value_counts() # Проверяем распределение целевого признака в тренировочной выборке
# Out:
# 0    599
# 1    370
# Name: покупательская_активность, dtype: int64

# %% [markdown]
# Можем заметить, что данных с одним целевым классом заметно больше, чем с другим, т.е. классы несбалансированны. Следовательно, имеет смысл создание пайплайна, в котором выбор лучшей модели будет осуществляться согласно метрике `roc-auc`, наиболее подходящей для таких ситуаций. К тому же, данная метрика интуитивно понятна, проста в интерпретации, и её легко сравнивать между разными моделями.

# %%
ohe_pipe = Pipeline( # Cоздаём пайплайн для подготовки признаков из списка ohe_columns
   [   
        (
            'simpleImputer_ohe', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ohe', 
            OneHotEncoder(drop='first', handle_unknown='error')
        )
    ]
)   

ord_pipe = Pipeline( # Cоздаём пайплайн для подготовки признаков из списка ord_columns
    [
        (
            'simpleImputer_before_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(
                categories=[
                    ['премиум', 'стандарт']
                ], 
                handle_unknown='error'
            )
        ),
        (
            'simpleImputer_after_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

data_preprocessor = ColumnTransformer( # Cоздаём общий пайплайн для подготовки данных
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

pipe_final = Pipeline([ # Создаём итоговый пайплайн
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

param_grid = [ # Выполняем перебор моделей и их гиперпараметров
    { # Словарь для модели DecisionTreeClassifier()
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 11),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },

    { # Словарь для модели KNeighborsClassifier() 
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(1, 20),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    { # Словарь для модели LogisticRegression()
        'models': [LogisticRegression(random_state=RANDOM_STATE)],
        'models__C': range(1, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    { # Словарь для модели SVC()
        'models': [SVC(random_state=RANDOM_STATE, probability= True)],
        'models__C': range(1, 10),
        'models__kernel': ['rbf', 'linear', 'sigmoid'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  

    }
]

# %%
label_encoder = LabelEncoder()

y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid,
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на кросс-валидации:', randomized_search.best_score_)
y_test_pred_proba = randomized_search.predict_proba(X_test)
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred_proba[:, 1])}')
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first'))]),
#                                                   ['разрешить_сообщать',
#                                                    'популярная_категория']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
#                                                                    SimpleImputer(strategy='most_frequent')),...
# ...

# %% [markdown]
# **Промежуточный вывод:**
#
# По итогу перебора моделей и их гиперпараметров лучшей моделью оказалась SVM с линейным ядром степени 8. Метрика на тестовой выборке составила 0.91, что является отличным показателем.

# %% [markdown]
# # Анализ важности признаков

# %% [markdown]
# Лучшей моделью оказалась SVM, однако она сложна в интерпретации. Поэтому на данном этапе мы рассмотрим степень влияния различных признаков на итоговое предсказание, и найдём те из них, которые вносят наибольший и наименьший вклад. Для этого отберём 20 наиболее влиятельных признаков и отсортируем их по убыванию значимости:

# %%
scaler = StandardScaler()
selector = SelectKBest(f_classif, k=20)
model = SVC(C=8, kernel='linear', probability=True, random_state=42)

X_train_scalled = pd.DataFrame(pipe_final.named_steps['preprocessor'].fit_transform(X_train), 
    columns= pipe_final.named_steps['preprocessor'].get_feature_names_out())
X_test_scalled =  pd.DataFrame(pipe_final.named_steps['preprocessor'].transform(X_test), 
    columns= pipe_final.named_steps['preprocessor'].get_feature_names_out())
selector.fit(X_train_scalled, y_train)
# Out:
# SelectKBest(k=20)

# %%
features_names = X_train_scalled.columns[selector.get_support(indices=True)]
features_names
# Out:
# Index(['ohe__разрешить_сообщать_нет',
#        'ohe__популярная_категория_косметика_и_аксессуары',
#        'ohe__популярная_категория_кухонная_посуда',
#        'ohe__популярная_категория_мелкая_бытовая_техника_и_электроника',
#        'ohe__популярная_категория_техника_для_красоты_и_здоровья',
#        'ohe__популярная_категория_товары_для_детей', 'ord__тип_сервиса',
#        'num__маркет_актив_6_мес', 'num__маркет_актив_тек_мес',
#        'num__длительность', 'num__акционные_покупки',
#        'num__средний_просмотр_категорий_за_визит',
#        'num__неоплаченные_продукты_штук_квартал', 'num__ошибка_сервиса',
#        'num__страниц_за_визит', 'num__выручка_предпредыдущий_месяц',
#        'num__выручка_предыдущий_месяц', 'num__выручка_текущий_месяц',
#        'num__время_предыдущий_месяц', 'num__время_текущий_месяц'],
#       dtype='object')

# %%
X_train_new = X_train_scalled[list(features_names)]
X_test_new = X_test_scalled[list(features_names)]

# %%
explainer = shap.LinearExplainer(model, X_test_new)
shap_values = explainer(X_test_new)
shap.plots.bar(shap_values, max_display=20)
# Out:
# ---------------------------------------------------------------------------
# InvalidModelError                         Traceback (most recent call last)
# /tmp/ipykernel_403/195790985.py in <module>
# ----> 1 explainer = shap.LinearExplainer(model, X_test_new)
#       2 shap_values = explainer(X_test_new)
#       3 shap.plots.bar(shap_values, max_display=20)
#
# /opt/conda/lib/python3.9/site-packages/shap/explainers/_linear.py in __init__(self, model, masker, link, nsamples, feature_perturbation, **kwargs)
#     127
#     128         # extract what we need from the given model object
# --> 129         self.coef, self.intercept = LinearExplainer._parse_model(model)
#     130
#     131         # extract the data
#
# /opt/conda/lib/python3.9/site-packages/shap/explainers/_linear.py in _parse_model(model)
#     309                 intercept = model.intercept_
#     310         else:
# --> 311             raise InvalidModelError("An unknown model type was passed: " + str(type(model)))
# ...

# %% [markdown]
# Построим несколько графиков, изображающих среднее значение вклада каждого признака в предсказание при помощи значений Шепли (SHAP):

# %%
shap.plots.beeswarm(shap_values, max_display=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_403/406544428.py in <module>
# ----> 1 shap.plots.beeswarm(shap_values, max_display=20)
#
# NameError: name 'shap_values' is not defined

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v1:</b> А можешь подсказать как это сделать? Я покопался в документации, попробовал разными способами, но размер либо не меняется, либо натыкаюсь на какую-нибудь ошибку. </div>

# %% [markdown]
# Наибольший вклад в прогнозирование вносят признаки:
# - среднее количество просмотренных за посещение сайта страниц и категорий;
# - среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
#
# Наименьший вклад в прогнозирование вносят признаки:
# - количество маркетинговых коммуникаций в текущем месяце;
# - практически все разделы популярных категорий (кроме мелкой бытовой техники и электроники);
# - количество дней с момента регистрации пользователя на сайте.
#
# **Промежуточный вывод:**
#
# На показатель активности пользователей сильно влияет количество просмотренных страниц и категорий. Соответственно, для повышения этой активности необходимо разработать или улучшить средства удержания пользователя на сайте. Одним из ключевых аспектов может стать улучшение пользовательского опыта (UX). Для этого стоит уделить внимание интуитивно понятному интерфейсу, который позволит пользователям легко находить необходимые товары и услуги, а также грамотно организованной навигации по сайту, четкому оформлению страниц и быстрому времени их загрузки.
#
# Также существенную роль в прогнозирование внесла среднемесячная доля акционных покупок пользователей, что приводит нас ко второму выводу: компании крайне важно предлагать своим клиентам персонализированный контент. Это может быть достигнуто с помощью алгоритмов, которые анализируют поведение пользователей на сайте и предлагают товары на основе их предыдущих поисков и покупок. Также можно использовать рассылку персонализированных предложений и акций, чтобы побудить пользователей вернуться на сайт.
#
# Ещё можно предложить создание системы лояльности и предоставление качественного обслуживания клиентам. Так, программы лояльности, которые предлагают бонусы, скидки или баллы за повторные покупки, могут значительно увеличить вероятность того, что пользователь вернётся на сайт. Дополнительно можно внедрить механизмы рекомендаций, основанные на принципах "люди, которые купили это, также купили...", что также поможет удерживать интерес покупателей. А быстрая и эффективная поддержка, возможность обратной связи и решение проблем клиентов могут существенно увеличить уровень удовлетворенности пользователей.

# %% [markdown]
# # Сегментация покупателей

# %% [markdown]
# Для того, чтобы  корректно разделить покупателей на различные группы, прежде всего обратимся к основной цели нашего проекта: удержать активность постоянных клиентов при помощи персонализированных предложений. Основной же проблемой, из которой проистекает эта цель, является снижение активности покупателей.
#
# По итогу перебора моделей на одном из предыдущих шагов мы научились с высокой точностью предсказывать, снизится ли покупательская активность пользователя в текущем месяце или же останется прежней. Теперь же мы можем ознакомиться с результатами предсказания. Для этого построим диаграмму рассеяния признака `прибыль` в зависимости от предсказанного значения признака `покупательская_активность` для всего датасета `df`:

# %%
predicted = randomized_search.predict_proba(X)[:, 1]
X['predicted'] = predicted
X.reset_index(inplace=True)
segment = X.merge(df_profit, on='id')

segment.plot.scatter(x='predicted', y='прибыль')
plot_describe('Диаграмма рассеяния признака "прибыль"',
              'Вероятность, что активность снизится', 'Прибыль от клиента')

# %% [markdown]
# Также добавим в датасет `df` новый столбец `прибыль_категория`, в котором присвоим каждому пользователю одну из категорий "низкая_прибыль", "средняя_прибыль" и "высокая_прибыль":

# %%
segment['прибыль'].describe() # Изучим описательные статистики признака

# %%
# Выделим категории на основании среднего значения и стандартного отклонения
segment['прибыль_категория'] = 'средняя_прибыль' # Значения в интервале ~(mean-std; mean+std)
segment.loc[segment['прибыль'] < 3, 'прибыль_категория'] = 'низкая_прибыль' # Значения меньшие mean-std
segment.loc[segment['прибыль'] > 5, 'прибыль_категория'] = 'высокая_прибыль' # Значения большие mean+std
segment.head() #Проверяем корректность присвоения категории

# %% [markdown]
# В конце концов, прежде, чем мы определимся с конкретной группой клиентов, будет целесообразно выделить "группу риска" — пользователей, вероятность снижения активности которых больше 0.6. Посмотрим, сколько таких в каждой из выделенных групп:

# %%
segment_high = segment[(segment['predicted'] >= 0.6) & (segment['прибыль_категория'] == 'высокая_прибыль')]
segment_medium = segment[(segment['predicted'] >= 0.6) & (segment['прибыль_категория'] == 'средняя_прибыль')]
segment_low = segment[(segment['predicted'] >= 0.6) & (segment['прибыль_категория'] == 'низкая_прибыль')]
print(f'Количество пользователей группы "высокая_прибыль", ожидаемая активность которых снизится: {segment_high.shape[0]}')
print(f'Количество пользователей группы "средняя_прибыль", ожидаемая активность которых снизится: {segment_medium.shape[0]}')
print(f'Количество пользователей группы "низкая_прибыль", ожидаемая активность которых снизится: {segment_low.shape[0]}')

# %% [markdown]
# Наибольший интерес для нас представляет группа наиболее обеспеченных клиентов, так как бизнесу будет потенциально чувствительна их потеря. Однако их количество недостаточно репрезентативно, поэтому для рассмотрения выберем более репрезентативную группу клиентов со средним доходом:

# %%
(segment_medium.groupby('популярная_категория')['прибыль'].sum().
    sort_values(ascending=False).plot(kind='barh', color='orange', alpha=0.5, label='средняя_прибыль'))
(segment_high.groupby('популярная_категория')['прибыль']
    .sum().sort_values(ascending=False).plot(kind='barh', color='blue', alpha=0.5, label='высокая_прибыль'))
plt.legend(loc='upper right')
plot_describe('Прибыль в зависимости от категории товара', 'Прибыль', 'Категория')

# %%
sb.relplot(data=segment_medium, x='акционные_покупки', y='прибыль', hue='маркет_актив_6_мес', size='тип_сервиса', aspect=2)
plot_describe('Зависимость прибыли от доли акционных покупок и количества маркетинговых коммуникаций',
              'Акционные покупки', 'Прибыль')

# %%
sb.relplot(data=segment_high, x='акционные_покупки', y='прибыль', hue='маркет_актив_6_мес', size='тип_сервиса', aspect=2)
plot_describe('Зависимость прибыли от доли акционных покупок и количества маркетинговых коммуникаций',
              'Акционные покупки', 'Прибыль')

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v1:</b> Сделал. </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v1:</b> Учёл. </div>

# %% [markdown]
# Сформулируем **промежуточный вывод** на основании данных признаков, а также выводов исследовательского анализа:
#
# Наиболее востребованными в данном сегменте оказались товары категорий "косметика и аксессуары", а также "товары для детей". К тому же, клиенты этого сегмента демонстрируют заметно больший интерес к акционным покупкам, чем клиенты сегмента с высокой прибылью.
#
# В совокупности эти два факта, подкреплённые также данными исследовательского анализа, могут свидетельствовать о том, что значительная часть этих клиентов была привлечена на сайт в результате какой-то акции, в рамках которой компания получила значительную прибыль. Однако, судя по всему, эта акция закончилась, и эти клиенты теперь не заинтересованы в данных товарах.
#
# Решением такой проблемы в долгосрочной перспективе представляется введение персонализированных подборок товаров или функции "Вместе с этим товаром также берут...", что помогло бы продать таким пользователям большее число товаров. В краткосрочной же перспективе с повышением интереса таких пользователей могло бы помочь возвращение акции и, возможно, её расширение и акцент на другие категории товаров.

# %% [markdown]
# # Общий вывод

# %% [markdown]
# **В ходе работы над проектом было разработано решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность. Описание решения:**
#
# - Одним из ключевых аспектов может стать улучшение пользовательского опыта (UX). Для этого стоит уделить внимание интуитивно понятному интерфейсу, который позволит пользователям легко находить необходимые товары и услуги, а также грамотно организованной навигации по сайту, четкому оформлению страниц и быстрому времени их загрузки.
# - Также существенную роль в прогнозирование внесла среднемесячная доля акционных покупок пользователей, что приводит нас ко второму выводу: компании крайне важно предлагать своим клиентам персонализированный контент. Это может быть достигнуто с помощью алгоритмов, которые анализируют поведение пользователей на сайте и предлагают товары на основе их предыдущих поисков и покупок. Также можно использовать рассылку персонализированных предложений и акций, чтобы побудить пользователей вернуться на сайт.
# - В качестве побочных аспектов можно предложить создание системы лояльности и предоставление качественного обслуживания клиентам. Так, программы лояльности, которые предлагают бонусы, скидки или баллы за повторные покупки, могут значительно увеличить вероятность того, что пользователь вернётся на сайт. Дополнительно можно внедрить механизмы рекомендаций, основанные на принципах "люди, которые купили это, также купили...", что также поможет удерживать интерес покупателей. А быстрая и эффективная поддержка, возможность обратной связи и решение проблем клиентов может существенно увеличить уровень удовлетворенности пользователей.
#
# **Изначально в данных были следующие проблемы:**
# - стилистические ошибки в названиях столбцов;
# - неочевидные дубликаты в данных, требующие дополнительной проверки.
#
# **В процессе предобработки данных были:**
# - Исправлены стилистические ошибки в названиях столбцов — все названия приведены к snake_case.
# - Удалены неявные дубликаты.
#
# **В рамках исследовательского анализа были:**
# - Рассмотрены количественные и категориальные признаки. Для количественных признаков построены гистограммы и диаграммы размаха, для категориальных — круговые диаграммы.
# - Было удалено аномальное значение в столбце`выручка`.
# - Были сделаны наблюдения и выводы о возможных причинах снижения активности пользователей. В частности:
#     - Пользователи со сниженной активностью просматривают меньшее количество страниц и категорий за визит, а также набирают в корзину много товаров, которые впоследствии не приобретают. Это может быть связано с привлечением их в магазин акцией, в рамках которой они покупают товары из одной-двух интересующих их категорий, а в другие даже не заглядывают.
#     - Предыдущее предположение также подтверждают и данные о покупках по акции. Заинтересованность в акционных предложениях у клиентов со сниженной активностью ощутимо выше, чем у клиентов с активностью неизменной, что может свидетельствовать о том, что эти клиенты более импульсивны и, возможно, в принципе приобретают товары на сайте исключительно в рамках акций, после чего их интерес резко угасает.
#     - На пользователей, чья активность в последнее время снизилась, приходится меньшее число рекламных предложений. Возможно, стоит увеличить количество рассылок и показов рекламы для таких клиентов.
#     - Пользователи со сниженной активностью в целом дольше зарегистрированы. В теории часть из них может негативно реагировать на какие-то изменения в подходе к оформлению рекламы или сайта (за счёт чего и снижается их активность). Было бы неплохо собрать от них обратную связь и понять, как можно улучшить пользовательский опыт от взаимодействия с сайтом.
#
# **Также был проведён корреляционный анализ, в ходе которого были выявлены типы взаимосвязей различных признаков с целевым.** На основе матрицы корреляций можно судить о сильной корреляции между некоторыми входными признаками (например, между выручкой за текущий и предыдущий месяцы), однако явных признаков сильной мультиколлинеарности (0.9 и более) с целевым признаком обнаружено не было.
#
# **Для автоматизации машинного обучения (перебора вариантов масштабирования, выбора оптимальной модели и её гиперпараметров) в рамках данного анализа были использованы пайплайны**. По итогу перебора моделей и их гиперпараметров лучшей моделью оказалась SVM с линейным ядром степени 8. Метрика на тестовой выборке составила 0.91.
#
# **Наибольший вклад в прогнозирование внесли признаки:**
# - среднее количество просмотренных за посещение сайта страниц и категорий;
# - среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
#
# **Наименьший вклад в прогнозирование внесли признаки:**
# - количество маркетинговых коммуникаций в текущем месяце;
# - практически все разделы популярных категорий (кроме мелкой бытовой техники и электроники);
# - количество дней с момента регистрации пользователя на сайте.
#
# **В рамках этапа сегментации пользователи были разделены на три категории в зависимости от приносимой компании прибыли — низкая, средняя и высокая.** Было решено изучить среднюю категорию пользователей ввиду наибольшей репрезентативности данной выборки.
#
# Наиболее востребованными в данном сегменте оказались товары категорий "косметика и аксессуары", а также "товары для детей". К тому же, клиенты этого сегмента продемонстрировали заметно больший интерес к акционным покупкам, чем клиенты сегмента с высокой прибылью.
#
# В совокупности эти два факта, подкреплённые также данными исследовательского анализа, привели нас к заключению о том, что значительная часть этих клиентов была привлечена на сайт в результате какой-то акции, в рамках которой компания получила значительную прибыль. Однако, судя по всему, эта акция закончилась, и эти клиенты теперь не заинтересованы в данных товарах.
#
# Решением такой проблемы в долгосрочной перспективе представляется введение персонализированных подборок товаров или функции "Вместе с этим товаром также берут...", что помогло бы продать таким пользователям большее число товаров. В краткосрочной же перспективе с повышением интереса таких пользователей могло бы помочь возвращение акции и, возможно, её расширение и акцент на другие категории товаров.
